# %% [markdown]
# <h1>Current Plot<h1>

# %% [markdown]
# <h3>Import<h3>

# %%
# IMPORTS

import numpy as np
import pandas as pd

import math as m
import statistics as stat

import matplotlib
import matplotlib.pyplot as plt
import matplotlib.animation as animation

import seaborn as sns
sns.set_theme()

# %% [markdown]
# <h3>Plot<h3>

# %%
# Ramo current
# Read the data into a pandas dataframe
#cur_time, step, ramo_cur, V_d, nrPart, nrElec, nrHole
filename = '../out/ramo_current.dt'
df_cur = pd.read_csv(filepath_or_buffer=filename, index_col = 1,delim_whitespace=True, \
                    header=None, names=['time', 'step', 'current', 'volt', 'nrPart', 'nrElec', 'nrIon', 'avg_mob', 'avg_part_speed','avg_elec_speed','avg_ion_speed','a','b','c'])
# print(stat.mean(df_cur['current'][-20::])*1e3)  
# Plot current in mA as a function of step
fig, ax = plt.subplots(figsize=(10, 6))
ax.plot(df_cur.index, df_cur['current']*1e3, label='Current')
ax.set_xlabel('Step')
ax.set_ylabel('Current [mA]')
plt.show()

# Plot current in mA as a function of step
fig, ax = plt.subplots(figsize=(10, 6))
ax.plot(df_cur.index, df_cur['nrElec'], label='nrElec')
ax.set_xlabel('Step')
ax.set_ylabel('Nr electrons')
plt.show()

# Plot the electron velocity
fig, ax = plt.subplots(figsize=(10, 6))
ax.plot(df_cur.index, df_cur['avg_elec_speed'], label='Electron velocity')
ax.set_xlabel('Step')
ax.set_ylabel('Electron velocity [m/s]')
plt.show()

# %%
print((1.602e-19)/(8.85e-12*(1e-9)**3)*(1e-9)**2)
# Out:
# 18.101694915254235
